# %% [markdown]
# ### Task 2
# With any tooling you prefer, please build a model and conduct analysis into predicting loan defaulters based on the below data set of employment status, loan amount and bank balance

# %%
#load libaries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV # advanced scaling pipeline
from sklearn.pipeline import FeatureUnion, make_pipeline
from sklearn.linear_model import LogisticRegression #Classification
from sklearn.metrics import accuracy_score,f1_score, roc_auc_score, confusion_matrix, precision_score, recall_score, classification_report

# %% [markdown]
# #### Data Importation and Exploratory Data Analysis
# We will explore the dataset and note down all potential issues observed from the dataset and then clean/preprocess/transform

# %%
#Read the data
df = pd.read_csv("Default_Fin.csv", index_col = [0])

#preview
df.head()
# Out:
#        Employed  Bank Balance  Annual Salary  Defaulted?
# Index
# 1             1       8754.36      532339.56           0
# 2             0       9806.16      145273.56           0
# 3             1      12882.60      381205.68           0
# 4             1       6351.00      428453.88           0
# 5             1       9427.92      461562.00           0

# %%
#data dimension
df.shape
# Out:
# (10000, 4)

# %%
#Check for missing values
df.isna().sum()
# Out:
# Employed         0
# Bank Balance     0
# Annual Salary    0
# Defaulted?       0
# dtype: int64

# %% [markdown]
# There are no missing values in any of the columns. We can explore the unique values in each column and assign meaning/context to the data.

# %%
#Examine the employed column
df["Employed"].unique()
# Out:
# array([1, 0], dtype=int64)

# %% [markdown]
# Column interpretation
# 0 = No (Not employed)
# 1 = Yes (Employed)

# %%
#descriptive statistics
df.describe()
# Out:
#            Employed  Bank Balance  Annual Salary    Defaulted?
# count  10000.000000  10000.000000   10000.000000  10000.000000
# mean       0.705600  10024.498524  402203.782224      0.033300
# std        0.455795   5804.579486  160039.674988      0.179428
# min        0.000000      0.000000    9263.640000      0.000000
# 25%        0.000000   5780.790000  256085.520000      0.000000
# 50%        1.000000   9883.620000  414631.740000      0.000000
# 75%        1.000000  13995.660000  525692.760000      0.000000
# max        1.000000  31851.840000  882650.760000      1.000000

# %%
#Create a histogram of each column to examine data distribution
df.hist(figsize = (10, 7))
plt.show()

# %%
#Create a histogram of each column to examine data distribution
import matplotlib.pyplot as plt

for column in df.columns:
    plt.figure()
    df.boxplot([column])

# %% [markdown]
# ### Some things to note on each column
# 1. Bank Balance - Appears to be skewed rightly with a few outliers. A large chunk of the values lie between 25000
# 2. Annual Salary - Appears to have a normal distribution. A normal distribution is a bell-shaped frequency distribution curve. Most of the data values in a normal distribution tend to cluster around the mean. The further a data point is from the mean, the less likely it is to occur.
# 3. Defaulted? - There is clearly a case of class imbalance. More of the group 0 (Non defaulters) than 1 (Defaulters).
# 4. Employed - is slightly unbalanced. More of the group 0 (Not employed) and group 1 (Employed)

# %% [markdown]
# #### Multi Variate Analysis
# We will cross the features and explore patterns and relationships

# %%
#Check for multicolinearity: This concept allows us to examine interdepence between variables in a mode
sns.heatmap(df.corr(), annot = True)
plt.show()

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = df,
                x = "Bank Balance",
                y = "Annual Salary", hue = "Defaulted?")
# Out:
# <AxesSubplot:xlabel='Bank Balance', ylabel='Annual Salary'>

# %%
#Average bank balance
df.groupby("Defaulted?")["Bank Balance"].mean()
# Out:
# Defaulted?
# 0     9647.324961
# 1    20973.858378
# Name: Bank Balance, dtype: float64

# %%
#Education level across customer types
df.groupby(["Defaulted?", "Employed"]).size()
# Out:
# Defaulted?  Employed
# 0           0           2817
#             1           6850
# 1           0            127
#             1            206
# dtype: int64

# %% [markdown]
# ### Class Imbalance

# %%
#Examine the % of defaulters to non defaulters
df["Defaulted?"].value_counts()/10000 * 100
# Out:
# 0    96.67
# 1     3.33
# Name: Defaulted?, dtype: float64

# %% [markdown]
# Distribution of groups on the defaulted column is at a ratio of 97% (Non-defaulters) ~ 3 (Defaulters).

# %%
#Examine the % of employed to un empployed
df["Employed"].value_counts()/10000 * 100
# Out:
# 1    70.56
# 0    29.44
# Name: Employed, dtype: float64

# %% [markdown]
# There is a 71% (employed = 1) ~ 29% (unemployed = 0)

# %% [markdown]
# #### Chi Square Test
# We will perform a chi square test between the categorical variables (Employed, Defaulted) and see if they are related.
# * The null hypothesis (H0) is; there exist no relationship
# * If alpha value is > 0.05, we accept the null, otherwise we reject( implying there is a relationship between both variables)

# %%
#Continge
from scipy.stats import chi2_contingency
  
# defining the table
data =  pd.crosstab(df['Employed'],
                            df['Defaulted?'], 
                               margins = False)
#data = [[207, 282, 241], [234, 242, 232]]
stat, p, dof, expected = chi2_contingency(data)
  
# interpret p-value
alpha = 0.05
print("p value is " + str(p))
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (H0 holds true)')
# Out:
# p value is 0.0004997256756210478
# Dependent (reject H0)

# %% [markdown]
# ## Data Transformation
# Having Identified the issues with the dataset, we will:
# **Normalize**
# 1. Clip outliers on bank balance and as well scale
# 2. Scale the Annual Salary
#
# **Oversample/Undersample**
# 1. The Defaulted? Column needs to be resampled. Using either Undersampling the majority (0) or oversampling the minority (1)
# 2. We will try out the same for Employed Column, but we will create a baseline model to examine the effects of each transformation on different experiments.

# %%
#Normalizing and Scaling the bank balance and Annual Salary
#make a copy
df_sklearn = df.copy()

df_sklearn.head()
# Out:
#        Employed  Bank Balance  Annual Salary  Defaulted?
# Index
# 1             1       8754.36      532339.56           0
# 2             0       9806.16      145273.56           0
# 3             1      12882.60      381205.68           0
# 4             1       6351.00      428453.88           0
# 5             1       9427.92      461562.00           0

# %%
#CLip outliers
#Values at the 99th percentile
out = df_sklearn["Bank Balance"].quantile(0.99)

df_sklearn = df[df_sklearn["Bank Balance"] <= out]

# %%
#Visualize Bank Balance
df_sklearn["Bank Balance"].hist() #Now at a normal distribution
# Out:
# <AxesSubplot:>

# %%
print("New dataset", df_sklearn.shape)
print("Original dataset", df.shape) #100 rows lost
# Out:
# New dataset (9900, 4)
# Original dataset (10000, 4)

# %% [markdown]
# Split data and scale Train and test variables separately to prevent data leak

# %%
##Feature and target names
features = df_sklearn.columns[0:3]
target = df_sklearn.columns[-1]

#X and y values
X = df_sklearn[features].values
y = df_sklearn[target].values

#splot
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=17)

print("The dimension of X_train is {}".format(X_train.shape))
print("The dimension of X_test is {}".format(X_test.shape))

#Scale features separately to prevent data leak
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# The dimension of X_train is (6930, 3)
# The dimension of X_test is (2970, 3)

# %% [markdown]
# ### Model Building
# We will build a baseline model to sample the predict performance of the data
#
# #### Experiment 1: Baseline Model

# %%
# copy the data
# fit a model to all features
#Create the LogReg
#STEP 1
RANDOM_STATE = 200 # seed to recreate results
model = LogisticRegression(random_state = RANDOM_STATE, solver = "liblinear") #solver = liblinear means the target var is binary

#STEP 2: Fit the model on our train dataset
model.fit(X_train, y_train) #Where X_train contains the features and y_train contains the target var

#STEP3: Test the Model performance: running a prediction
predictions = model.predict(X_test)

#STEP4:
actual = y_test

# %%
#confusion matrix
confusion_matrix(actual, predictions)
# Out:
# array([[2897,    5],
#        [  63,    5]], dtype=int64)

# %%
#Accuracy:
accuracy_score(actual, predictions)
# Out:
# 0.9771043771043771

# %%
#recall
recall_score(actual, predictions)
# Out:
# 0.07352941176470588

# %%
#precision
precision_score(actual, predictions)
# Out:
# 0.5

# %%
#ROC Curve function
def plot_roc_curve(y_true, y_score):
    from sklearn.metrics import roc_curve, auc
    
    fpr, tpr, _ = roc_curve(y_true=y_true, y_score=y_score)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(9, 6))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC (auc = {:0.2}'.format(roc_auc))
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")

# %%
#Plot roc curve
#roc curve
y_score = model.predict_proba(X_test)[:,1]

#round probab values with python
np.round(y_score,1)

#roc curve
plot_roc_curve(actual, y_score)

# %% [markdown]
# ### Experiment 2
# #### Dealing with Class Imbalance
# From the first model, recall is poor and below average. We will build a baseline model by undersampling the majority group.

# %%
#Get the number of each groups
class_0_maj_count, class_1_min_count = df_sklearn["Defaulted?"].value_counts()

#Separate the classes
class_0_maj = df_sklearn[df_sklearn["Defaulted?"] == 0]
class_1_min = df_sklearn[df_sklearn["Defaulted?"]== 1]

#resample using random undersampling of the majority class
class_0_rand = class_0_maj.sample(class_1_min_count, random_state = 10)

#Combine the new sample (class_0_rand) with the minority class (class_1_min)
df_rand = pd.concat([class_0_rand, class_1_min], axis = 0)

#preview
df_rand
# Out:
#        Employed  Bank Balance  Annual Salary  Defaulted?
# Index
# 7260          0      15499.32      193368.24           0
# 5980          1       8622.96      150860.28           0
# 2814          0       6994.44      212766.60           0
# 6933          1       3507.24      726986.76           0
# 5238          1       1349.64      411840.36           0
# ...         ...           ...            ...         ...
# 9857          1      23685.84      328080.12           1
# 9884          1      16027.32      451144.08           1
# 9922          0      19534.80      210564.00           1
# 9950          1      21003.00      618947.28           1
# 9952          1      18187.32      584262.12           1
#
# [514 rows x 4 columns]

# %%
#Data size
df_rand["Defaulted?"].value_counts()
# Out:
# 0    257
# 1    257
# Name: Defaulted?, dtype: int64

# %%
#split data, scale and Build model
##Feature and target names
features = df_rand.columns[0:3]
target = df_rand.columns[-1]

#X and y values
X = df_rand[features].values
y = df_rand[target].values

#splot
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=17)

print("The dimension of X_train is {}".format(X_train.shape))
print("The dimension of X_test is {}".format(X_test.shape))

#Scale features separately to prevent data leak
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# The dimension of X_train is (359, 3)
# The dimension of X_test is (155, 3)

# %%
#Buildmodel
# copy the data
# fit a model to all features
#Create the LogReg
#STEP 1
RANDOM_STATE = 200 # seed to recreate results
model = LogisticRegression(random_state = RANDOM_STATE, solver = "liblinear") #solver = liblinear means the target var is binary

#STEP 2: Fit the model on our train dataset
model.fit(X_train, y_train) #Where X_train contains the features and y_train contains the target var

#STEP3: Test the Model performance: running a prediction
predictions = model.predict(X_test)

#STEP4:
actual = y_test

# %%
#confusion matrix
print("Confusion matrix",confusion_matrix(actual, predictions))

#Accuracy:
print("Accuracy score", accuracy_score(actual, predictions))

#recall
print("Recall Score", recall_score(actual, predictions))

#precision
print("Precision", precision_score(actual, predictions))
# Out:
# Confusion matrix [[71  8]
#  [ 9 67]]
# Accuracy score 0.8903225806451613
# Recall Score 0.881578947368421
# Precision 0.8933333333333333

# %%
#Plot roc curve
#roc curve
y_score = model.predict_proba(X_test)[:,1]

#round probab values with python
np.round(y_score,1)

#roc curve
plot_roc_curve(actual, y_score)

# %%
#Save model from E2

# %% [markdown]
# #### Experiment 2 Results
# This model appears to have a better performance as the recall, precision have improved. with almost 90% accuracy

# %% [markdown]
# ### Experiment 3: Using a grid search model with Logistic Regression model

# %%
# use hyperparameter tuning combined with a scaling pipeline
scaler = StandardScaler() # scaling function

#same three lines below for grid search acroos hyperparameters C and penalty as in Method 3
param_grid = dict(C=[0.00001,0.0001,0.001,0.01,0.1,1,10],penalty=['l1','l2'])
regr = LogisticRegression(random_state=RANDOM_STATE, solver='liblinear')
cv = GridSearchCV(estimator=regr, param_grid=param_grid, scoring='average_precision')

pipeline = make_pipeline(scaler, cv) # here we SCALE the data so that all features are in the same "ballpark"

pipeline.fit(X_train, y_train) # fit the model to the SCALED data

y_true = y_test
y_pred = pipeline.predict(X_test)
y_score = pipeline.predict_proba(X_test)[:, 1]

# %%
# a) extract model accuracy
accuracy_score(y_true, y_pred)
# Out:
# 0.8838709677419355

# %%
precision_score(y_true,y_pred)
# Out:
# 0.8625

# %%
# b) display a confusion matrix
confusion_matrix(y_true,y_pred)
# Out:
# array([[68, 11],
#        [ 7, 69]], dtype=int64)

# %%
recall_score(y_true,y_pred)
# Out:
# 0.9078947368421053

# %% [markdown]
# #### Experiment 3 Results
#
# Using a Grid search, does improve the recall. Typically, we can explore model 2

# %% [markdown]
# ### Observations
# 1. From the data exploration, the scatterplot shows a large cluster of defualters are customers with high bank balance. In fact this group have their average bank balance almost twice as much as the non defaulters. Perhaps for behavioral reasons? We will need more data to explore that possibilty.
# 2. The chi square test also proves an established dependence between the education and propensity to default.
#
# #### Model Choice
# * The logistic regression model is choice here, largely due to the imbalance problem. Powerful models like Random forests,KNN, due to how delicate the data is in terms of data balance.
# * Harnessing the L1 and L2 Regularization techniques, we fit a model that generalizes well enough.
#
#
# ### Recommendation
# 1. The model needs to go through alpha-beta tests (Using model from Experiment 2 and 3). We could use more powerful models, however, class imbalance poses a challenge.
# 2. Some more detailed customer analytics should be done, to understand customer behaviors at a more granular level. These variables can be orchestrated as new features into the predictive model.
# 3. Engineering new data points
